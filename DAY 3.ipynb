# %%
import pandas as pd
import os

# %%
os.chdir('D:/Phython/DAY 3')

# %%
data1=pd.read_csv('data_clean.csv')
data1
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data2=pd.read_csv('data_clean.csv',index_col=0)
data2
#removing SR NO coloumn from csv file
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4     67     5    1  2010    67       S
# 2     36.0    118.0   8.0     72     5    2  2010    72       C
# 3     12.0    149.0  12.6     74     5    3  2010    74      PS
# 4     18.0    313.0  11.5     62     5    4  2010    62       S
# 5      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 154   41.0    190.0   7.4     67     5    1  2010    67       C
# 155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 156    NaN    145.0  13.2     77     9   27  2010    77       S
# 157   14.0    191.0  14.3     75     9   28  2010    75       S
# 158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
type(data2)
# Out:
# pandas.core.frame.DataFrame

# %%
data2.shape
# Out:
# (158, 9)

# %%
data2.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
#data Type conversion

# %%
data2.head(24) #to see 25th row
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 1    41.0    190.0   7.4     67     5    1  2010    67       S
# 2    36.0    118.0   8.0     72     5    2  2010    72       C
# 3    12.0    149.0  12.6     74     5    3  2010    74      PS
# 4    18.0    313.0  11.5     62     5    4  2010    62       S
# 5     NaN      NaN  14.3     56     5    5  2010    56       S
# 6    28.0      NaN  14.9     66     5    6  2010    66       C
# 7    23.0    299.0   8.6     65     5    7  2010    65      PS
# 8    19.0     99.0  13.8     59     5    8  2010    59       C
# 9     8.0     19.0  20.1     61     5    9  2010    61      PS
# 10    NaN    194.0   8.6     69     5   10  2010    69       S
# 11    7.0      NaN   6.9      C     5   11  2010    74       C
# 12   16.0    256.0   9.7     69     5   12  2010    69      PS
# 13   11.0    290.0   9.2     66     5   13  2010    66       S
# 14   14.0    274.0  10.9     68     5   14  2010    68       S
# ...

# %%
data2[data2['Month']=='May'] # Error is in last line (Unable to parse string "May" at position 2)
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 24   32.0     92.0  12.0     61   May   24  2010    61       C

# %%
data2['Month']=pd.to_numeric(data2['Month'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "May"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15392/289942641.py in <module>
# ----> 1 data2['Month']=pd.to_numeric(data2['Month'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
data2['Month']=pd.to_numeric(data2['Month'],errors='coerce') #Puts NAN on errors

# %%
data2['Temp C']=pd.to_numeric(data2['Temp C'],errors='coerce')

# %%
data2['Weather']=data2['Weather'].astype('category') #astype(Cat) helps object to category

# %%
data2.head(24)
# Out:
#     Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 1    41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 2    36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 3    12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 4    18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 5     NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# 6    28.0      NaN  14.9    66.0    5.0    6  2010    66       C
# 7    23.0    299.0   8.6    65.0    5.0    7  2010    65      PS
# 8    19.0     99.0  13.8    59.0    5.0    8  2010    59       C
# 9     8.0     19.0  20.1    61.0    5.0    9  2010    61      PS
# 10    NaN    194.0   8.6    69.0    5.0   10  2010    69       S
# 11    7.0      NaN   6.9     NaN    5.0   11  2010    74       C
# 12   16.0    256.0   9.7    69.0    5.0   12  2010    69      PS
# 13   11.0    290.0   9.2    66.0    5.0   13  2010    66       S
# ...

# %%
data2[data2.duplicated()] #print the duplicated rows
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 157   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
dataOG=data2
dataOG
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 2     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 3     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 4     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 5      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 154   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 155   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 156    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 157   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 158   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data2[data2.duplicated()].shape  #Count of duplicated rows
# Out:
# (1, 9)

# %%
data2_cleaned1=data2.drop_duplicates()

# %%
data2_cleaned1.shape
# Out:
# (157, 9)

# %%
data2.shape
# Out:
# (158, 9)

# %%
data2_cleaned2=data2_cleaned1.drop('Temp C',axis=1)

# %%
data2_cleaned2
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4    5.0    1  2010    67       S
# 2     36.0    118.0   8.0    5.0    2  2010    72       C
# 3     12.0    149.0  12.6    5.0    3  2010    74      PS
# 4     18.0    313.0  11.5    5.0    4  2010    62       S
# 5      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 153   20.0    223.0  11.5    9.0   30  2010    68       S
# 154   41.0    190.0   7.4    5.0    1  2010    67       C
# 155   30.0    193.0   6.9    9.0   26  2010    70      PS
# 156    NaN    145.0  13.2    9.0   27  2010    77       S
# 158   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
#Rename Coloumn Name
data2_cleaned3=data2_cleaned2.rename({'Solar.R': 'Solar'},axis=1)

# %%
data2_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 1     41.0  190.0   7.4    5.0    1  2010    67       S
# 2     36.0  118.0   8.0    5.0    2  2010    72       C
# 3     12.0  149.0  12.6    5.0    3  2010    74      PS
# 4     18.0  313.0  11.5    5.0    4  2010    62       S
# 5      NaN    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 153   20.0  223.0  11.5    9.0   30  2010    68       S
# 154   41.0  190.0   7.4    5.0    1  2010    67       C
# 155   30.0  193.0   6.9    9.0   26  2010    70      PS
# 156    NaN  145.0  13.2    9.0   27  2010    77       S
# 158   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
#dataf
dataf=data2_cleaned3

# %%
#count NA in coloumns
dataOG.isnull().sum()
dataOG=dataf.dropna()
dataOG.isnull().sum()
dataOG.shape
# Out:
# (111, 8)

# %%
import matplotlib.pyplot as plt

# %%
dataOG_box=dataOG.Ozone
plt.boxplot(dataOG_box)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26253da1250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26253da18b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26253d83dc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x26253da1fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26253dae3a0>],
#  'means': []}

# %%
plt.boxplot(dataOG['Ozone'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26253e8fd90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26253e9e4f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26253e8fa00>],
#  'medians': [<matplotlib.lines.Line2D at 0x26253e9ec10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26253e9efa0>],
#  'means': []}

# %%
box=plt.boxplot(dataOG['Ozone'])
dataOG['Ozone'].hist()   #SECON Way
# Out:
# <AxesSubplot:>

# %%
[temp.get_ydata() for temp in box['fliers']]  #Outliars is sqaid Fliers #check graph for o/p check
# Out:
# [array([135., 168.])]

# %%
[temp.get_ydata()[1] for temp in box['whiskers']] #Whiskers are the range is boc plot
# Out:
# [1.0, 122.0]

# %%
RGB 0 TO 9 A TO F 123456789ABCDEF HEXADECI NUMBERING SYSTEM.
RED GREEN BLUE

# %%
import seaborn as sns
cols=dataf.columns
colours=['#000099','#ffff00'] #specify the colours - yellow is missing,blue is not missing
sns.heatmap(dataf[cols].isnull(),cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
dataf[dataf.isnull().any(axis=1)].head()
dataf[dataf.isnull().any(axis=1)].head(10) #shows NAN
# Out:
#     Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 5     NaN    NaN  14.3    5.0    5  2010    56       S
# 6    28.0    NaN  14.9    5.0    6  2010    66       C
# 10    NaN  194.0   8.6    5.0   10  2010    69       S
# 11    7.0    NaN   6.9    5.0   11  2010    74       C
# 24   32.0   92.0  12.0    NaN   24  2010    61       C
# 25    NaN   66.0  16.6    5.0   25  2010    57      PS
# 26    NaN  266.0  14.9    5.0   26  2010    58       C
# 27    NaN    NaN   8.0    5.0   27  2010    57      PS
# 32    NaN  286.0   8.6    6.0    1  2010    78       S
# 33    NaN  287.0   9.7    6.0    2  2010    74       C

# %%
dataf.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
meann=dataf['Ozone'].mean()

# %%
print(meann)
# Out:
# 41.81512605042017

# %%
dataf['Ozone']=dataf['Ozone'].fillna(meann) #Replacing NAN by mean

# %%
dataf.shape
# Out:
# (157, 8)

# %%
dataf.head()
# Out:
#        Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 1  41.000000  190.0   7.4    5.0    1  2010    67       S
# 2  36.000000  118.0   8.0    5.0    2  2010    72       C
# 3  12.000000  149.0  12.6    5.0    3  2010    74      PS
# 4  18.000000  313.0  11.5    5.0    4  2010    62       S
# 5  41.815126    NaN  14.3    5.0    5  2010    56       S

# %%
#MODE GIVES MAXIMUM FREQUENCY

# %%
obj_col=dataf.Ozone
modee=obj_col.mode().iloc[0] #mode=(41,12) is in series we need the most recurring which will be first hence [0]
type(modee)
print(modee)
# Out:
# 41.81512605042017

# %%
obj_col=obj_col.fillna(obj_col.mode().iloc[0])
obj_col.isnull().sum()    #NAN is zero
# Out:
# 0

# %%
#correlation
dataf.corr() #check value is more than 0.5
# Out:
#           Ozone     Solar      Wind     Month       Day  Year      Temp
# Ozone  1.000000  0.308687 -0.520004  0.132860 -0.021916   NaN  0.606500
# Solar  0.308687  1.000000 -0.057407 -0.094012 -0.155663   NaN  0.273558
# Wind  -0.520004 -0.057407  1.000000 -0.166216  0.029900   NaN -0.441228
# Month  0.132860 -0.094012 -0.166216  1.000000  0.050055   NaN  0.398516
# Day   -0.021916 -0.155663  0.029900  0.050055  1.000000   NaN -0.122787
# Year        NaN       NaN       NaN       NaN       NaN   NaN       NaN
# Temp   0.606500  0.273558 -0.441228  0.398516 -0.122787   NaN  1.000000

# %% [markdown]
# # Transformations

# %%
dataf=pd.concat([dataf,obj_col],axis=1)
dataf
# Out:
#          Ozone  Solar  Wind  Month  Day  Year  Temp Weather      Ozone  \
# 1    41.000000  190.0   7.4    5.0    1  2010    67       S  41.000000
# 2    36.000000  118.0   8.0    5.0    2  2010    72       C  36.000000
# 3    12.000000  149.0  12.6    5.0    3  2010    74      PS  12.000000
# 4    18.000000  313.0  11.5    5.0    4  2010    62       S  18.000000
# 5    41.815126    NaN  14.3    5.0    5  2010    56       S  41.815126
# ..         ...    ...   ...    ...  ...   ...   ...     ...        ...
# 153  20.000000  223.0  11.5    9.0   30  2010    68       S  20.000000
# 154  41.000000  190.0   7.4    5.0    1  2010    67       C  41.000000
# 155  30.000000  193.0   6.9    9.0   26  2010    70      PS  30.000000
# 156  41.815126  145.0  13.2    9.0   27  2010    77       S  41.815126
# 158  18.000000  131.0   8.0    9.0   29  2010    76       C  18.000000
#
#          Ozone
# 1    41.000000
# 2    36.000000
# 3    12.000000
# 4    18.000000
# 5    41.815126
# ..         ...
# ...

# %%
datafd=dataf.drop(['Ozone'],axis=1,inplace=True)
#Bymistake deleted Wheather

# %%
dataf
# Out:
#      Solar  Wind  Month  Day  Year  Temp
# 1    190.0   7.4    5.0    1  2010    67
# 2    118.0   8.0    5.0    2  2010    72
# 3    149.0  12.6    5.0    3  2010    74
# 4    313.0  11.5    5.0    4  2010    62
# 5      NaN  14.3    5.0    5  2010    56
# ..     ...   ...    ...  ...   ...   ...
# 153  223.0  11.5    9.0   30  2010    68
# 154  190.0   7.4    5.0    1  2010    67
# 155  193.0   6.9    9.0   26  2010    70
# 156  145.0  13.2    9.0   27  2010    77
# 158  131.0   8.0    9.0   29  2010    76
#
# [157 rows x 6 columns]

# %%
dataf=pd.concat([dataf,obj_col],axis=1)
dataf
# Out:
#      Solar  Wind  Month  Day  Year  Temp      Ozone
# 1    190.0   7.4    5.0    1  2010    67  41.000000
# 2    118.0   8.0    5.0    2  2010    72  36.000000
# 3    149.0  12.6    5.0    3  2010    74  12.000000
# 4    313.0  11.5    5.0    4  2010    62  18.000000
# 5      NaN  14.3    5.0    5  2010    56  41.815126
# ..     ...   ...    ...  ...   ...   ...        ...
# 153  223.0  11.5    9.0   30  2010    68  20.000000
# 154  190.0   7.4    5.0    1  2010    67  41.000000
# 155  193.0   6.9    9.0   26  2010    70  30.000000
# 156  145.0  13.2    9.0   27  2010    77  41.815126
# 158  131.0   8.0    9.0   29  2010    76  18.000000
#
# [157 rows x 7 columns]

# %%
obj_col1=data2_cleaned3.Weather

# %%
obj_col1=data2_cleaned3.Weather

# %%
data2_cleaned3=pd.concat([dataf,obj_col1],axis=1)
data2_cleaned3
# Out:
#      Solar  Wind  Month  Day  Year  Temp      Ozone Weather
# 1    190.0   7.4    5.0    1  2010    67  41.000000       S
# 2    118.0   8.0    5.0    2  2010    72  36.000000       C
# 3    149.0  12.6    5.0    3  2010    74  12.000000      PS
# 4    313.0  11.5    5.0    4  2010    62  18.000000       S
# 5      NaN  14.3    5.0    5  2010    56  41.815126       S
# ..     ...   ...    ...  ...   ...   ...        ...     ...
# 153  223.0  11.5    9.0   30  2010    68  20.000000       S
# 154  190.0   7.4    5.0    1  2010    67  41.000000       C
# 155  193.0   6.9    9.0   26  2010    70  30.000000      PS
# 156  145.0  13.2    9.0   27  2010    77  41.815126       S
# 158  131.0   8.0    9.0   29  2010    76  18.000000       C
#
# [157 rows x 8 columns]

# %%
# !pip install pandas.profiling==2.7.1
# !pip install sweetviz
# Out:
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=6bc8143c1db69a20f567f96915bc529089eb70cdea9e581153790535bbe28b29
#   Stored in directory: c:\users\rahul\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# ...
#   Created wheel for imagehash: filename=ImageHash-4.2.1-py2.py3-none-any.whl size=295207 sha256=09782d954b3baae08c319daae82d560cda36e61c975a017158cf4bb22b9aa908
#   Stored in directory: c:\users\rahul\appdata\local\pip\cache\wheels\51\f9\a5\740af2fdb0ad1edf79aabdc41531be0b6f0b2e2be684c388cf
# Successfully built htmlmin imagehash
# ...

# %%
import pandas_profiling as pp
import sweetviz as sv

# %%
EDA_report=pp.ProfileReport(data1)

# %%
EDA_report.to_file(output_file='report.html') #error
# Out:
# Summarize dataset:   0%|          | 0/22 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15392/776295198.py in <module>
# ----> 1 EDA_report.to_file(output_file='report.html')
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in to_file(self, output_file, silent)
#     222             data = self.to_json()
#     223         else:
# --> 224             data = self.to_html()
#     225             if output_file.suffix != ".html":
#     226                 suffix = output_file.suffix
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in to_html(self)
#     322
#     323         """
# --> 324         return self.html
#     325
#     326     def to_json(self) -> str:
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in html(self)
#     150     def html(self):
# ...

# %%
sweet_report=sv.analyze(data1)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
sweet_report.show_html('weather_report.html')
# Out:
# Report weather_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
